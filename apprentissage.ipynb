# %%
### Code/Notes pour apprendre à utiliser GitHub

# 1️⃣ Si on crée un NOUVEAU repository sur GitHub :
# - Initialiser un dépôt Git local :
#     git init

# - Ajouter le dépôt distant (remote) :
#     git remote add origin git@github.com:TonNomUtilisateur/NomDuRepo.git

# - Ajouter les fichiers à Git :
#     git add nom_du_fichier

# - Créer un commit :
#     git commit -m "Message décrivant les changements"

# - Pousser sur GitHub :
#     git push -u origin main
#   (le '-u' définit la branche principale comme upstream pour les futurs push)

# 2️⃣ Pour les étapes générales après avoir déjà lié un dépôt distant :
#     git add nom_du_fichier (ou pour tous les fichiers: git add . )
#     git commit -m "Message décrivant les changements"
#     git push
#   (la première fois, si la branche locale n’est pas encore liée, utiliser :
#     git push -u origin main)
